# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/drive/MyDrive/HR_capstone_dataset.csv')
data
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
data.isna().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
data['tenure']=data['time_spend_company']
data.drop('time_spend_company',axis=1)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  Work_accident  left  promotion_last_5years  \
# 0                       157              0     1                      0
# 1                       262              0     1                      0
# ...

# %%
data.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# Department                object
# salary                    object
# tenure                     int64
# dtype: object

# %%
data.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
data.duplicated().sum()
# Out:
# 3008

# %%
data=data.drop_duplicates(keep='first')

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=data,x='average_montly_hours',y='number_project',orient='h')
# Out:
# <Axes: xlabel='average_montly_hours', ylabel='number_project'>

# %%
sns.boxplot(data['tenure'],orient='h')
# Out:
# <Axes: >

# %%
q75=data['tenure'].quantile(0.75)
q25=data['tenure'].quantile(0.25)
iqr=q75-q25
print(f'iqr = {iqr}')
upper_limit=q75+1.5*iqr
lower_limit=q25-1.5*iqr
outliers=data[(data['tenure']>upper_limit)|(data['tenure']<lower_limit)]
print(f'No Of Outliers : {len(outliers)}')
# Out:
# iqr = 1.0
# No Of Outliers : 824

# %%
df=data[(data['tenure']<=upper_limit)&(data['tenure']>=lower_limit)]
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
# 5                0.41             0.50               2                   153
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
# 5                   3              0     1                      0      sales
#
#    salary  tenure
# 0     low       3
# ...

# %%
fig,ax=plt.subplots(1,2,figsize=(15,5))
# Define short-tenured employees
ax[0].set_title('Number of projects histogram', fontsize='14')
ax[1].set_title('Monthly hours by number of projects', fontsize='14')
sns.histplot(data=df,x='number_project',hue='left',multiple='dodge',shrink=2,ax=ax[0])
sns.boxplot(data=df,x='average_montly_hours',y='number_project',hue='left',ax=ax[1],orient='h')
# Out:
# <Axes: title={'center': 'Monthly hours by number of projects'}, xlabel='average_montly_hours', ylabel='number_project'>

# %%
fig,ax=plt.subplots(1,2,figsize=(15,5))
sns.scatterplot(data=df,x='average_montly_hours',y='satisfaction_level',hue='left', alpha=0.4,ax=ax[0])
ax[0].set_title('Monthly hours by last evaluation score', fontsize='14')
sns.histplot(data=df, x='tenure', hue='left', multiple='dodge', shrink=3, ax=ax[1])
ax[1].set_title('Tenure histogram', fontsize='14')
# Out:
# Text(0.5, 1.0, 'Tenure histogram')

# %%
# Define short-tenured employees

# Define long-tenured employees


ax=sns.histplot(data=df, x='tenure', hue='salary', discrete=1,
             hue_order=['low', 'medium', 'high'], multiple='dodge', shrink=.5)
plt.title('Salary histogram by tenure', fontsize='14')
for i in ax.containers:
    ax.bar_label(i)

# %%
df['Department'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
plt.figure(figsize=(15,5))
ax=sns.histplot(data=df,x='Department',hue='left',multiple='dodge',shrink=0.5)
for i in ax.containers:
  ax.bar_label(i)
plt.title('Counts of stayed/left by department')
# Out:
# Text(0.5, 1.0, 'Counts of stayed/left by department')

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
df['Department']=l.fit_transform(df['Department'])
df['salary']=l.fit_transform(df['salary'])
# Out:
# <ipython-input-20-cb68598aef76>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Department']=l.fit_transform(df['Department'])
# <ipython-input-20-cb68598aef76>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['salary']=l.fit_transform(df['salary'])

# %%
df.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# Department                 int64
# salary                     int64
# tenure                     int64
# dtype: object

# %%
df['left'].unique()
# Out:
# array([1, 0])

# %%
X=df.drop('left',axis=1)
y=df['left']

# %%
from sklearn.preprocessing import MinMaxScaler
min=MinMaxScaler()
X=min.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,stratify=y,random_state=45)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(X_test,y_test)
# Out:
# 0.8276633840644584

# %%
from sklearn.metrics import f1_score,precision_score,recall_score,accuracy_score,confusion_matrix,roc_auc_score
def evaluation(yt,yp,mname):
  '''
  Takes yt=ytest,yp=ypreds and calculate all the metrics
  '''
  acc=round(accuracy_score(yt,yp),2)*100
  pre=round(precision_score(yt,yp),2)*100
  re=round(recall_score(yt,yp),2)*100
  f1=round(f1_score(yt,yp),2)*100
  auc = round(roc_auc_score(yt, yp),2)*100

  table = pd.DataFrame()
  table = pd.DataFrame({'model': [mname],
                          'precision': [pre],
                          'recall': [re],
                          'F1': [f1],
                          'accuracy': [acc],
                          'auc': [auc]
                        })
  return table

# %%
def plot_cm(yt,yp,title=None):
  '''
  Takes yt=ytest,yp=ypreds and calculate confusion metrics and plot it n heatmap
  Provide title to be shown
  '''
  cm=confusion_matrix(yt,yp)
  sns.heatmap(cm,annot=True,fmt='d')
  plt.title(title,fontsize=10)
  plt.xlabel('Predicted')
  plt.ylabel('Actual')

# %%
y_preds=lr.predict(X_test)

# %%
lr_result=evaluation(y_test,y_preds,'Logistic Regression')

# %%
lr_result
# Out:
#                  model  precision  recall    F1  accuracy   auc
# 0  Logistic Regression       48.0    23.0  31.0      83.0  59.0

# %%
plot_cm(y_test,y_preds,'Logistic Regression Heatmap')

# %%
df.left.value_counts(normalize=True)*100
# Out:
# 0    83.146772
# 1    16.853228
# Name: left, dtype: float64

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier()
tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
tree.score(X_test,y_test)
# Out:
# 0.9713518352730528

# %%
y_predstree=tree.predict(X_test)

# %%
tree_result=evaluation(y_test,y_predstree,'Decision Tree')
tree_result
# Out:
#            model  precision  recall    F1  accuracy   auc
# 0  Decision Tree       92.0    91.0  91.0      97.0  95.0

# %%
plot_cm(y_test,y_predstree,'Decision Tree Heatmap')

# %% [markdown]
# Hyperparameter Tuning

# %%
grid = {'max_depth': [3,5, None],
             'max_features': [1.0],
             'min_samples_leaf': [1,2,3],
             'min_samples_split': [2,3,4],

             }
scoring = {'accuracy', 'precision', 'recall', 'f1', 'roc_auc'}

# %%
from matplotlib.backend_bases import GraphicsContextBase
gst=GridSearchCV(tree,grid,verbose=1,scoring=scoring,cv=5,refit='roc_auc')

# %%
gst.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [3, 5, None], 'max_features': [1.0],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 3, 4]},
#              refit='roc_auc',
#              scoring={'roc_auc', 'precision', 'recall', 'f1', 'accuracy'},
#              verbose=1)

# %%
gst.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=5, max_features=1.0, min_samples_leaf=2)

# %%
gst.best_params_
# Out:
# {'max_depth': 5,
#  'max_features': 1.0,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2}

# %%
y_predstree1=gst.predict(X_test)

# %%
tree_h=evaluation(y_test,y_predstree1,'Decision Tree Hyperparameter')
tree_h
# Out:
#                           model  precision  recall    F1  accuracy   auc
# 0  Decision Tree Hyperparameter       97.0    91.0  94.0      98.0  95.0

# %%
plot_cm( y_preds,y_predstree1,'Decision Tree Heatmap After Hyperparameter Tuning')

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier()
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
clf.score(X_test,y_test)
# Out:
# 0.9829901521933752

# %%
y_predsr=clf.predict(X_test)

# %%
rf_result=evaluation(y_test,y_predsr,'Random Forest')
rf_result
# Out:
#            model  precision  recall    F1  accuracy   auc
# 0  Random Forest       99.0    91.0  95.0      98.0  95.0

# %%
plot_cm(y_test,y_predsr,'Heatmap Using Random Forest')

# %% [markdown]
# Hyperparameter Tuning

# %%
grid= {'max_depth': [3,5, None],
             'max_features': [1.0],
             'min_samples_leaf': [1,2,3],
             'min_samples_split': [2,3,4],
             'n_estimators': [300, 500],
             }

# %%
clfg=GridSearchCV(clf,grid,scoring=scoring,refit='roc_auc',cv=5,verbose=1)

# %%
# %%time
clfg.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# CPU times: user 19min 40s, sys: 2.34 s, total: 19min 43s
# Wall time: 20min 3s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [3, 5, None], 'max_features': [1.0],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 3, 4],
#                          'n_estimators': [300, 500]},
#              refit='roc_auc',
#              scoring={'roc_auc', 'precision', 'recall', 'f1', 'accuracy'},
#              verbose=1)

# %%
clfg.best_params_
# Out:
# {'max_depth': 5,
#  'max_features': 1.0,
#  'min_samples_leaf': 2,
#  'min_samples_split': 3,
#  'n_estimators': 300}

# %%
clfg.best_estimator_
# Out:
# RandomForestClassifier(max_depth=5, max_features=1.0, min_samples_leaf=2,
#                        min_samples_split=3, n_estimators=300)

# %%
clfg.score(X_test,y_test)
# Out:
# 0.9774957184015175

# %%
y_predsg=clfg.predict(X_test)

# %%
rfh_result=evaluation(y_test,y_predsg,'Random Forest hyperparameter')
rfh_result
# Out:
#                           model  precision  recall    F1  accuracy   auc
# 0  Random Forest hyperparameter       97.0    92.0  94.0      98.0  95.0

# %%
plot_cm(y_test,y_predsg,'Random Forest After Hyperparameter Tuning')

# %% [markdown]
# ### Feature Engneering

# %%
df=df.drop('satisfaction_level',axis=1)

# %%
df['overworked']=df['average_montly_hours']
df['overworked'].min(),df['overworked'].max()
# Out:
# (96, 310)

# %%
df['average_montly_hours'].mean()
# Out:
# 200.14453299901496

# %% [markdown]
# If you assume a work week of 40 hours and two weeks of vacation per year, then the average number of working hours per month of employees working Monday–Friday = 50 weeks * 40 hours per week / 12 months = 166.67 hours per month.

# %%
df['overworked'] = (df['overworked'] > 175).astype(int)
df['overworked']
# Out:
# 0        0
# 2        1
# 3        1
# 4        0
# 5        0
#         ..
# 11985    1
# 11986    0
# 11987    1
# 11992    1
# 11999    1
# Name: overworked, Length: 11167, dtype: int64

# %%
df=df.drop('average_montly_hours',axis=1)

# %%
X=df.drop('left',axis=1)
y=df['left']

# %% [markdown]
# ## Round 2

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=0)

# %%
grid2= {'max_depth':[4, 6, 8, None],
             'min_samples_leaf': [2, 5, 1],
             'min_samples_split': [2, 4, 6]
             }

# %%
tree2 = GridSearchCV(tree, grid2, scoring=scoring, cv=4, refit='roc_auc')

# %%
tree2.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [4, 6, 8, None],
#                          'min_samples_leaf': [2, 5, 1],
#                          'min_samples_split': [2, 4, 6]},
#              refit='roc_auc',
#              scoring={'roc_auc', 'precision', 'recall', 'f1', 'accuracy'})

# %%
tree2.score(X_test,y_test)
# Out:
# 0.9643763075254004

# %%
ypreds2=tree2.predict(X_test)

# %%
tree_round2_results=evaluation(y_test,ypreds2,'Tree Round 2')
tree_round2_results
# Out:
#           model  precision  recall    F1  accuracy   auc
# 0  Tree Round 2       85.0    92.0  88.0      96.0  94.0

# %%
plot_cm(y_test,ypreds2,"Heatmap Decision Tree Round 2")

# %%
tree_h,tree_round2_results
# Out:
# (                          model  precision  recall    F1  accuracy   auc
#  0  Decision Tree Hyperparameter       97.0    91.0  94.0      98.0  95.0,
#            model  precision  recall    F1  accuracy   auc
#  0  Tree Round 2       85.0    92.0  88.0      96.0  94.0)

# %% [markdown]
# ### Random forest round 2

# %%
rfgrid = {'max_depth': [3,5, None],
             'max_features': [1.0],
             'max_samples': [0.7, 1.0],
             'min_samples_leaf': [1,2,3],
             'min_samples_split': [2,3,4],
             'n_estimators': [300, 500],
             }
rf2 = GridSearchCV(clf, rfgrid, scoring=scoring, cv=4, refit='roc_auc')

# %%
rf2.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=4, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [3, 5, None], 'max_features': [1.0],
#                          'max_samples': [0.7, 1.0],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 3, 4],
#                          'n_estimators': [300, 500]},
#              refit='roc_auc',
#              scoring={'roc_auc', 'precision', 'recall', 'f1', 'accuracy'})

# %%
rf2.best_estimator_
# Out:
# RandomForestClassifier(max_depth=5, max_features=1.0, max_samples=0.7,
#                        min_samples_leaf=3, n_estimators=500)

# %%
rf2.best_params_
# Out:
# {'max_depth': 5,
#  'max_features': 1.0,
#  'max_samples': 0.7,
#  'min_samples_leaf': 3,
#  'min_samples_split': 2,
#  'n_estimators': 500}

# %%
rf2.score(X_test,y_test)
# Out:
# 0.9724791916508642

# %%
rf2y_preds=rf2.predict(X_test)

# %%
rf2_result=evaluation(y_test,rf2y_preds,'Random Forest Round 2')
rf2_result
# Out:
#                    model  precision  recall    F1  accuracy   auc
# 0  Random Forest Round 2       89.0    92.0  90.0      97.0  95.0

# %%
plot_cm(y_test,rf2y_preds,'Random Forest 2 Heatmap')

# %%
rfh_result,rf2_result
# Out:
# (                          model  precision  recall    F1  accuracy   auc
#  0  Random Forest hyperparameter       97.0    92.0  94.0      98.0  95.0,
#                     model  precision  recall    F1  accuracy   auc
#  0  Random Forest Round 2       89.0    92.0  90.0      97.0  95.0)

# %%
tree_importance=pd.DataFrame(tree2.best_estimator_.feature_importances_,columns=['importance'],index=X.columns)
tree_importance=tree_importance.sort_values(by='importance',ascending=False)
tree_importance=tree_importance[tree_importance['importance']!=0]
tree_importance
# Out:
#                     importance
# number_project        0.438814
# last_evaluation       0.334243
# time_spend_company    0.167796
# overworked            0.056993
# tenure                0.001564
# salary                0.000590

# %%
sns.barplot(data=tree_importance, x="importance", y=tree_importance.index, orient='h')
plt.title("Decision Tree: Feature Importances for Employee Leaving", fontsize=12)
plt.ylabel("Feature")
plt.xlabel("Importance")
plt.show()

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(85,20))
plot_tree(tree2.best_estimator_, max_depth=6, fontsize=14, feature_names=X.columns,
          class_names={0:'stayed', 1:'left'}, filled=True);
plt.show()

# %%
rf_importance=pd.DataFrame(rf2.best_estimator_.feature_importances_,columns=['importance'],index=X.columns)
rf_importance=tree_importance.sort_values(by='importance',ascending=False)
rf_importance=tree_importance[tree_importance['importance']!=0]
rf_importance
# Out:
#                     importance
# number_project        0.438814
# last_evaluation       0.334243
# time_spend_company    0.167796
# overworked            0.056993
# tenure                0.001564
# salary                0.000590

# %%
sns.barplot(data=rf_importance,x='importance',y=rf_importance.index)
# Out:
# <Axes: xlabel='importance'>

# %%
lr_result
# Out:
#                  model  precision  recall    F1  accuracy   auc
# 0  Logistic Regression       48.0    23.0  31.0      83.0  59.0

# %%
tree_round2_results
# Out:
#           model  precision  recall    F1  accuracy   auc
# 0  Tree Round 2       85.0    92.0  88.0      96.0  94.0

# %%
rf2_result
# Out:
#                    model  precision  recall    F1  accuracy   auc
# 0  Random Forest Round 2       89.0    92.0  90.0      97.0  95.0

# %% [markdown]
# ## Summary Of Model Results

# %% [markdown]
# The logistic regression model achieved precision of 48%, recall of 23%, f1-score of 31% (all weighted averages), and accuracy of 83%,auc of 59% on the test set.
#
# After conducting feature engineering, the decision tree model achieved AUC of 94%, precision of 85%, recall of 92%, f1-score of 88%, and accuracy of 96%, on the test set.
#
# After conducting feature engineering, the Random Forest model achieved AUC of 95%, precision of 89.0%, recall of 92%, f1-score of 90%, and accuracy of 97%, on the test set.
#
#  The random forest modestly outperformed the decision tree model.
